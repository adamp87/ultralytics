# %%
# %cd /content/
# !git clone https://github.com/adamp87/ultralytics.git main
# %cd /content/main
# !pip install -e .
# Out:
# /content
# Cloning into 'main'...
# remote: Enumerating objects: 18731, done.
# remote: Counting objects: 100% (409/409), done.
# remote: Compressing objects: 100% (324/324), done.
# remote: Total 18731 (delta 202), reused 221 (delta 84), pack-reused 18322
# Receiving objects: 100% (18731/18731), 10.61 MiB | 21.06 MiB/s, done.
# Resolving deltas: 100% (12903/12903), done.
# /content/main
# Obtaining file:///content/main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.9-0.editable-py3-none-any.whl size=22618 sha256=fb072328c2580e9a7f03798b75a901bca5445c6ca597c1138c40e52c1095484d
# ...

# %%
# !yolo export model=yolov8n.pt data=coco128.yaml format=tflite int8 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 213MB/s]
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# 2024-02-07 13:40:26.921992: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-07 13:40:26.922061: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-07 13:40:26.923517: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# coco128.yaml is a subset with 128 images of the coco dataset, execute with coco.yaml for full validation, with coco128 for fast testing
# !yolo val model=yolov8n_saved_model/yolov8n_full_integer_quant.tflite data=coco.yaml imgsz=640 int8
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# 2024-02-07 13:55:19.081289: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-07 13:55:19.081350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-07 13:55:19.082904: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading yolov8n_saved_model/yolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# ...

# %%
# %cd /content/
# !git clone https://github.com/adamp87/ultralytics.git /content/detached
# %cd /content/detached
# !git checkout tflite_detach_dirty
# !pip install -e .
# Out:
# /content
# Cloning into '/content/detached'...
# remote: Enumerating objects: 18731, done.
# remote: Counting objects: 100% (409/409), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 18731 (delta 202), reused 214 (delta 92), pack-reused 18322
# Receiving objects: 100% (18731/18731), 10.61 MiB | 19.75 MiB/s, done.
# Resolving deltas: 100% (12899/12899), done.
# /content/detached
# Branch 'tflite_detach_dirty' set up to track remote branch 'tflite_detach_dirty' from 'origin'.
# Switched to a new branch 'tflite_detach_dirty'
# Obtaining file:///content/detached
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
# ...

# %%
# !yolo export model=yolov8n.pt data=coco128.yaml format=tflite int8 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 79.6MB/s]
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 64, 80, 80), (1, 80, 80, 80), (1, 64, 40, 40), (1, 80, 40, 40), (1, 64, 20, 20), (1, 80, 20, 20)) (6.2 MB)
# 2024-02-08 14:53:20.608362: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 14:53:20.608435: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# coco128.yaml is a subset with 128 images of the coco dataset, execute with coco.yaml for full validation, with coco128 for fast testing
# !yolo val model=yolov8n_saved_model/yolov8n_full_integer_quant.tflite data=coco.yaml imgsz=640 int8
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# 2024-02-08 15:07:05.000726: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 15:07:05.000831: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 15:07:05.005107: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading yolov8n_saved_model/yolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# ...
